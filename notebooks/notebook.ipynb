# %%
import pandas as pd

# %%
data_path = "./data/2019-Oct-recsys-1m.csv"
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#                   event_time event_type  product_id          category_code  \
# 0  2019-10-14 14:27:10+00:00       view    11300020  electronics.telephone
# 1  2019-10-14 14:28:22+00:00       view    11300020  electronics.telephone
# 2  2019-10-14 14:28:51+00:00       view    11300022  electronics.telephone
# 3  2019-10-14 14:30:30+00:00       view    11300022  electronics.telephone
# 4  2019-10-14 14:31:01+00:00       view    11300099  electronics.telephone
#
#        brand  price    user_id                          user_session
# 0  panasonic  42.44  282977436  b9a7936a-abd9-4330-ae3b-df38c77b4ff4
# 1  panasonic  42.44  282977436  b9a7936a-abd9-4330-ae3b-df38c77b4ff4
# 2  panasonic  49.42  282977436  b9a7936a-abd9-4330-ae3b-df38c77b4ff4
# 3  panasonic  49.42  282977436  b9a7936a-abd9-4330-ae3b-df38c77b4ff4
# 4  panasonic  54.03  282977436  b9a7936a-abd9-4330-ae3b-df38c77b4ff4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199462 entries, 0 to 1199461
# Data columns (total 8 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   event_time     1199462 non-null  object
#  1   event_type     1199462 non-null  object
#  2   product_id     1199462 non-null  int64
#  3   category_code  1199462 non-null  object
#  4   brand          1131728 non-null  object
#  5   price          1199462 non-null  float64
#  6   user_id        1199462 non-null  int64
#  7   user_session   1199462 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 73.2+ MB
